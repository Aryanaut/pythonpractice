# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
fig, ax = plt.subplots()
a = 0
radius = int(input())
center = input("Enter coords with a space: ")
center = center.split()
coords = []
for coord in center:
    coords.append(int(coord))
xCoords = []
yCoords = []
while a < 360:
    ra = math.radians(a)
    y = (radius*(math.sin(ra)))+coords[1]
    x = (radius*(math.cos(ra)))+coords[0]
    yCoords.append(y)
    xCoords.append(x)
    a += 2
    
plt.plot(xCoords, yCoords)
plt.scatter(coords[0], coords[1])
# Out:
# 2
# Enter coords with a space: 3 4
